# %%
#데이터프레임 생성
import pandas as pd

pd.DataFrame({
    '이름': ['김일번', '이이번', '박삼번'],
    '나이': ['11', '22', '33'],
    '주소': ['경기도', '서울', '인천'],
    '혈액형': ['A', 'B', 'O']
    })

# %%
#Series 작성
import pandas as pd

pd.Series(['김일번', '이이번', '박삼번'],
          index = [3, 1, 2]
          )

# %%
#엑셀 불러오기
import pandas as pd

df =pd.read_excel(
    'pandas_data_xlsx.xlsx', index_col='종목코드', sheet_name='Sheet1')

display(df)

# %%
import pandas as pd

df = pd.read_csv('pandas_data_csv.csv')

df.loc[:,['종목명','종가']]
df.loc[[0,4,5],:]
df.iloc[[1,4,6],[4,5]]
df.iloc[[5,4,6],:]

#display(df)
# Out:
#      종목코드    종목명    시장구분          소속부     종가   대비   등락률     시가     고가     저가  \
# 5  211270   AP위성  KOSDAQ        우량기업부  12940  -60 -0.46  13000  13020  12730
# 4  265520  AP시스템  KOSDAQ        우량기업부  19420  140  0.73  19480  19630  19110
# 6  139050   BF랩스  KOSDAQ  관리종목(소속부없음)   2805    0  0.00      0      0      0
#
#       거래량        거래대금          시가총액     상장주식수
# 5   62008   797412620  195165013760  15082304
# 4  229282  4430793245  292286943820  15050821
# 6       0           0   24247965555   8644551
